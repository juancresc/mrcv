# %%
# !blastn -task blastn -query data/res/sRNA_DEG.fasta  -subject data/data/miRNAs/mature.fa -outfmt "6 qseqid sseqid qstart qend sstart send score length mismatch gaps gapopen nident pident qlen slen qcovs" > data/res/sRNA_DEG_mirbase.blast.csv

# %%
import pandas as pd
import numpy as np
data_dir = 'data'
lb = 'iwgsc_4_2_19'
blast_out = data_dir + '/res/' + lb + '/degs_mirbase.blast.csv'

# %%
deg_file = data_dir + '/res/' + lb + '/deg_data.csv'
df_deg = pd.read_csv(deg_file,sep="\t")
#df_deg.loc[pd.isnull(df_deg['MajorRNA']), 'MajorRNA'] = df_deg['Gene']
print('Res len:',len(df_deg.index))
df_deg.head(3)
# Out:
# Res len: 15187
#                      Gene     baseMean  log2FoldChange     lfcSE       stat  \
# 0   UUGUACCAACUGUAAACUCGU  2533.093634       11.194181  0.811249  13.798700
# 1  AGAUUCUGUUGAACUCGUUCUC  1837.516100       10.742077  0.796753  13.482320
# 2   AAUGAACAUCACAAACAGCCU  1082.287516        9.626418  0.738611  13.033145
#
#          pvalue          padj  X21dpiR1C.trimmed  X21dpiR3C.trimmed  \
# 0  2.594910e-43  3.138284e-38           2.165950           1.422006
# 1  1.987567e-41  1.201882e-36           1.082975           2.844011
# 2  7.927133e-39  3.195692e-34           3.248925           1.422006
#
#    X21dpiR1T.trimmed  X21dpiR3T.trimmed                     seq #Locus MIRNA  \
# 0        5540.768053        4588.018528   UUGUACCAACUGUAAACUCGU    NaN   NaN
# 1        3698.211073        3647.926343  AGAUUCUGUUGAACUCGUUCUC    NaN   NaN
# 2        2376.091998        1948.387137   AAUGAACAUCACAAACAGCCU    NaN   NaN
#
#   DicerCall
# 0       NaN
# 1       NaN
# 2       NaN

# %%
df_blast = pd.read_csv(blast_out,sep="\t", header=None)
df_blast.columns = ['qseqid','sseqid','qstart','qend','sstart','send','score','length','mismatch','gaps','gapopen','nident','pident','qlen','slen','qcovs']
print('initial:',len(df_blast.index))
# Out:
# initial: 57302

# %%
df_blast = df_blast[df_blast.length >= df_blast.qlen - 4]
df_blast = df_blast[df_blast.mismatch <= 2]
print('len -4:',len(df_blast.index))
# Out:
# len -4: 1565

# %%
df_res = pd.merge(df_deg, df_blast[['qseqid','sseqid']], left_on='Gene', right_on='qseqid', how='left')
df_res = df_res.drop(['qseqid'], axis=1)
df_res.rename(columns={'sseqid': 'miRBASE'}, inplace=True)
df_res = df_res.replace(np.nan, '', regex=True)
print(len(df_res.index))
df_res.head(12)
# Out:
# 16455
#                                      Gene     baseMean  log2FoldChange  \
# 0                   UUGUACCAACUGUAAACUCGU  2533.093634       11.194181
# 1                  AGAUUCUGUUGAACUCGUUCUC  1837.516100       10.742077
# 2                   AAUGAACAUCACAAACAGCCU  1082.287516        9.626418
# 3                   AACCCGUGGACAAUACUCCCU  2420.352064       11.621420
# 4                         CAUUGUUCAAAGGCC   932.491103        9.767691
# 5                   GUUGAUUUCACUGUAGGCUAG  2109.265328       11.390165
# 6   GGUGGCUGUAGUUUAGUGGUGAGAAUUCCACGUUGUC   264.370279        5.444196
# 7                   UUUCUGGUUGACAUAAGUGAC  1314.590300       10.740928
# 8                  UAACCCGUGGACAAUACUCCCU  1113.560401       10.528688
# 9                   GAGAAUUGAGAUUUUGGGCCU  1060.422787       10.455004
# 10                  GUGCCGCGAAUCAGAAGACUC  1155.607150       10.568082
# 11                      CGUGAUGGGGAUAGAUC   383.666719        3.939069
#
# ...

# %%
df_res.to_csv(data_dir + '/res/' + lb + '/sRNA_DEG_mirbase.csv', sep='\t', index=None)

# %%
rules = {'seq':'first','log2FoldChange':'first','miRBASE':','.join,'MIRNA':'first'}
df_res_ = df_res.groupby('Gene',as_index=False).agg(rules)

# %%
df_res_.tail()
# Out:
#                                      Gene                                 seq  \
# 15182  UUUUUUGAGUCCGAGAUACUGUUACCCGCCUUGA  UUUUUUGAGUCCGAGAUACUGUUACCCGCCUUGA
# 15183               UUUUUUGAUUGGAAUGCUGCC               UUUUUUGAUUGGAAUGCUGCC
# 15184              UUUUUUGAUUGGAAUGCUGCCU              UUUUUUGAUUGGAAUGCUGCCU
# 15185              UUUUUUGGAAUCGAUAUCGACC              UUUUUUGGAAUCGAUAUCGACC
# 15186                    UUUUUUUCGACCUGUC                    UUUUUUUCGACCUGUC
#
#        log2FoldChange miRBASE MIRNA
# 15182        8.322724
# 15183        9.733295
# 15184        6.359340
# 15185        6.434340
# 15186        8.754371

# %%
df_res_.to_csv(data_dir + '/res/' + lb + '/sRNA_DEG_mirbase.formatted.csv', sep='\t', index=None)

# %%
len(df_res_[~df_res_.Gene.str.contains('Cluster') & (df_res_.miRBASE != "")].index)
# Out:
# 189

# %%
len(df_res_[~df_res_.Gene.str.contains('Cluster')].index)
# Out:
# 14471

# %%
len(df_res_[(df_res_.MIRNA == 'Y') & (df_res_.miRBASE != "")].index)
# Out:
# 10

# %%
df_res_[(df_res_.MIRNA == 'Y')]
# Out:
#                Gene                     seq  log2FoldChange  \
# 7336  Cluster_16054  UACUGUGGGCACUUAUUUGACA       -0.715709
# 7346  Cluster_16796  AUGCCGUGUUGUUCUGAAAGAA       -0.942752
# 7368  Cluster_17194    UAGCCAAGAAUGACUUGCCU       -1.343073
# 7391  Cluster_18555    GGUGGGUCUUCUUGGCUAGC       -1.400455
# 7568  Cluster_27225  UGGGCAAGUCAUCCUGGCUACC       -1.047406
# 7597  Cluster_28963   UCGCUUGGUGCAGAUCGGGAC       -0.659671
# 7650  Cluster_32170   UGUAGAUACUCCCUAAGGCUU       -1.198635
# 7688  Cluster_33754   UGUAGAUACUCCCUAAGGCUU       -1.092349
# 7748  Cluster_35737   UGUAGAUACUCCCUAAGGCUU       -1.029754
# 7859   Cluster_6291   UGCCAAAGGAGAGUUGCCCUG       -1.578261
# 7934   Cluster_9839    AGGCGGUUACCUUGGCUAGC       -1.796546
#
#                                                 miRBASE MIRNA
# 7336                                     tae-miR9669-5p     Y
# 7346                                                        Y
# ...

# %%
df_res_[(df_res_.MIRNA == 'Y') ].to_csv('data/res/iwgsc_4_2_19/mirbase.Y.deg.csv', index=None)

# %%
df_res_[(df_res_.miRBASE != "") & (df_res_.MIRNA == '') ].to_csv('data/res/iwgsc_4_2_19/mirbase.noncluster.deg.csv', index=None)

# %%
d = df_res_[(df_res_.miRBASE != "") & (df_res_.MIRNA == '') ]

# %%
len(d[d.log2FoldChange > 0].index), len(d[d.log2FoldChange < 0].index)
# Out:
# (179, 10)

# %%
from Bio import SeqIO
from Bio.SeqRecord import SeqRecord
from Bio.Seq import Seq
file_deg_mirna_fasta = '/home/juan/Desktop/juan/bio/mrcv/data/res/mirna_deg_fasta.fa'

# %%
buffer_seqs = []
for k,v in df_deg.iterrows():
    seq = SeqRecord(Seq(v.seq), id=v.Gene, description=str(v.log2FoldChange))
    buffer_seqs.append(seq)

# %%
SeqIO.write(buffer_seqs, file_deg_mirna_fasta, "fasta")
# Out:
# 15187
