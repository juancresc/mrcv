# %%
import pandas as pd
import numpy as np
from Bio import SeqIO
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
data_dir = 'data'
lb = 'iwgsc_4_2_19/'
output_fasta = data_dir + '/res/' + lb + '/sRNA_DEG.fasta'

# %%
results_file = data_dir + '/res/' + lb + '/Results.txt'
df_res = pd.read_csv(results_file,sep="\t")
#df_res = df_res[df_res.DicerCall.isin(['20','21','22'])]
print('Res len:',len(df_res.index))
# Out:
# ('Res len:', 38496)

# %%
df_res.head()
# Out:
#          #Locus       Name  Length  Reads    RPM  UniqueReads  FracTop Strand  \
# 0    1A:209-460  Cluster_1     252    124  0.973           64    1.000      +
# 1    1A:688-753  Cluster_2      66     86  0.675            0    1.000      +
# 2  1A:5808-6115  Cluster_3     308    239  1.876          103    1.000      +
# 3  1A:7054-7211  Cluster_4     158    216  1.695           69    1.000      +
# 4  1A:7470-8084  Cluster_5     615    558  4.379          364    0.998      +
#
#                                    MajorRNA  MajorRNAReads ...  DicerCall  \
# 0  CGCGGAUUGCUCGAGCUGCUCACGCGGCGAGAGCGGGUCG             25 ...          N
# 1                      UAGACCGACUUUGUGAAAUG              5 ...          N
# 2                        GGUAUAACAUCAUAGGAU             31 ...          N
# 3                       CACAUGACUCUCGGCAACG             29 ...          N
# 4              CCGGACCCUGUCGCCCCACGAGGCGCCA             51 ...          N
#
#   MIRNA PhaseScore  Short  Long  20  21  22  23  24
# 0    N2       -1.0     29    79   2   1   4   5   4
# 1    N2       -1.0      8    56   7   1   3   6   5
# 2    N2       -1.0    116    59  13  14  18   9  10
# 3    N2       -1.0     87    56  12  30   9  18   4
# 4    N2       -1.0     56   416  16  21  12  25  12
#
# [5 rows x 21 columns]

# %%
df_res = df_res[['Name','MajorRNA','#Locus','MIRNA','DicerCall']]
df_res.head()
# Out:
#         Name                                  MajorRNA        #Locus MIRNA  \
# 0  Cluster_1  CGCGGAUUGCUCGAGCUGCUCACGCGGCGAGAGCGGGUCG    1A:209-460    N2
# 1  Cluster_2                      UAGACCGACUUUGUGAAAUG    1A:688-753    N2
# 2  Cluster_3                        GGUAUAACAUCAUAGGAU  1A:5808-6115    N2
# 3  Cluster_4                       CACAUGACUCUCGGCAACG  1A:7054-7211    N2
# 4  Cluster_5              CCGGACCCUGUCGCCCCACGAGGCGCCA  1A:7470-8084    N2
#
#   DicerCall
# 0         N
# 1         N
# 2         N
# 3         N
# 4         N

# %%
deg_file = data_dir + '/res/' + lb + 'diffexpr-results.0.01.csv'
df_deg = pd.read_csv(deg_file,sep=",",comment='#')
print('DEG len:',len(df_deg.index))
# Out:
# ('DEG len:', 15187)

# %%
up = len(df_deg[(~df_deg.Gene.str.contains('Clust')) & (df_deg.log2FoldChange > 0)].index)
down = len(df_deg[(~df_deg.Gene.str.contains('Clust')) & (df_deg.log2FoldChange < 0)].index)
(up, down)
# Out:
# (13719, 752)

# %%
up = len(df_deg[(df_deg.Gene.str.contains('Clust')) & (df_deg.log2FoldChange > 0)].index)
down = len(df_deg[(df_deg.Gene.str.contains('Clust')) & (df_deg.log2FoldChange < 0)].index)
(up, down)
# Out:
# (490, 226)

# %%
df_deg['seq'] = ''
for k,v in df_deg.iterrows():
    if 'Cluster' in v.Gene:
        df_deg.loc[k, 'Gene'] = v.Gene.split('_')[0] + '_' + v.Gene.split('_')[1]
    else:
        df_deg.loc[k, 'Gene']  = v.Gene.split('_')[0] 
        df_deg.loc[k, 'seq'] = v.Gene.split('_')[0]

# %%
df_deg.tail()
# Out:
#                                      Gene    baseMean  log2FoldChange  \
# 15182                CUUAAGGUAGCCAAAUGCCU   22.179823        2.671161
# 15183                        Cluster_2593  142.617625       -1.195305
# 15184                    CGAAAGAUGGUGAACU  220.696039        0.771691
# 15185              UCGGUCCAUAUCCGGUGUGGGC   15.061301        3.032649
# 15186  UAAAUACAGGCGAGAGACCGAUAGCGAACAAGUA   42.743617        2.260646
#
#           lfcSE      stat    pvalue      padj  X21dpiR1C.trimmed  \
# 15182  0.827816  3.226759  0.001252  0.009973           2.165950
# 15183  0.370452 -3.226612  0.001253  0.009977         199.267398
# 15184  0.239192  3.226241  0.001254  0.009990         158.114349
# 15185  0.940069  3.225987  0.001255  0.009997           2.165950
# 15186  0.700760  3.225993  0.001255  0.009997          10.829750
#
#        X21dpiR3C.trimmed  X21dpiR1T.trimmed  X21dpiR3T.trimmed  \
# 15182           9.954040          46.184556          30.414747
# 15183         197.658788          67.553529         105.990786
# 15184         167.796669         261.942257         294.930882
# 15185           4.266017          37.223373          16.589862
# 15186          18.486074          99.262329          42.396314
#
#                                       seq
# 15182                CUUAAGGUAGCCAAAUGCCU
# 15183
# 15184                    CGAAAGAUGGUGAACU
# 15185              UCGGUCCAUAUCCGGUGUGGGC
# 15186  UAAAUACAGGCGAGAGACCGAUAGCGAACAAGUA

# %%
df_deg_res = pd.merge(df_deg, df_res,left_on='Gene', right_on='Name' , how='left')
#only some cols
#df_deg_res = df_deg_res['#Locus','Name','MajorRNA','log2FoldChange']

# %%
df_deg_res.tail()
# Out:
#                                      Gene    baseMean  log2FoldChange  \
# 15182                CUUAAGGUAGCCAAAUGCCU   22.179823        2.671161
# 15183                        Cluster_2593  142.617625       -1.195305
# 15184                    CGAAAGAUGGUGAACU  220.696039        0.771691
# 15185              UCGGUCCAUAUCCGGUGUGGGC   15.061301        3.032649
# 15186  UAAAUACAGGCGAGAGACCGAUAGCGAACAAGUA   42.743617        2.260646
#
#           lfcSE      stat    pvalue      padj  X21dpiR1C.trimmed  \
# 15182  0.827816  3.226759  0.001252  0.009973           2.165950
# 15183  0.370452 -3.226612  0.001253  0.009977         199.267398
# 15184  0.239192  3.226241  0.001254  0.009990         158.114349
# 15185  0.940069  3.225987  0.001255  0.009997           2.165950
# 15186  0.700760  3.225993  0.001255  0.009997          10.829750
#
#        X21dpiR3C.trimmed  X21dpiR1T.trimmed  X21dpiR3T.trimmed  \
# 15182           9.954040          46.184556          30.414747
# 15183         197.658788          67.553529         105.990786
# 15184         167.796669         261.942257         294.930882
# 15185           4.266017          37.223373          16.589862
# 15186          18.486074          99.262329          42.396314
#
#                                       seq          Name  \
# 15182                CUUAAGGUAGCCAAAUGCCU           NaN
# 15183                                      Cluster_2593
# 15184                    CGAAAGAUGGUGAACU           NaN
# 15185              UCGGUCCAUAUCCGGUGUGGGC           NaN
# 15186  UAAAUACAGGCGAGAGACCGAUAGCGAACAAGUA           NaN
#
#                     MajorRNA                  #Locus MIRNA DicerCall
# 15182                    NaN                     NaN   NaN       NaN
# 15183  UUUCGUGAAGGCUUCUAACUU  1B:578093667-578094261    N5        21
# 15184                    NaN                     NaN   NaN       NaN
# 15185                    NaN                     NaN   NaN       NaN
# 15186                    NaN                     NaN   NaN       NaN

# %%
df_deg_res = df_deg_res.replace(np.nan, '', regex=True)
df_deg_res = df_deg_res.replace('nan', '', regex=True)
df_deg_res.seq = df_deg_res.seq.astype(str) + df_deg_res.MajorRNA.astype(str)

# %%
df_deg_res = df_deg_res.drop(['Name'], axis=1).drop(['MajorRNA'], axis=1)

# %%
df_deg_res.tail()
# Out:
#                                      Gene    baseMean  log2FoldChange  \
# 15182                CUUAAGGUAGCCAAAUGCCU   22.179823        2.671161
# 15183                        Cluster_2593  142.617625       -1.195305
# 15184                    CGAAAGAUGGUGAACU  220.696039        0.771691
# 15185              UCGGUCCAUAUCCGGUGUGGGC   15.061301        3.032649
# 15186  UAAAUACAGGCGAGAGACCGAUAGCGAACAAGUA   42.743617        2.260646
#
#           lfcSE      stat    pvalue      padj  X21dpiR1C.trimmed  \
# 15182  0.827816  3.226759  0.001252  0.009973           2.165950
# 15183  0.370452 -3.226612  0.001253  0.009977         199.267398
# 15184  0.239192  3.226241  0.001254  0.009990         158.114349
# 15185  0.940069  3.225987  0.001255  0.009997           2.165950
# 15186  0.700760  3.225993  0.001255  0.009997          10.829750
#
#        X21dpiR3C.trimmed  X21dpiR1T.trimmed  X21dpiR3T.trimmed  \
# 15182           9.954040          46.184556          30.414747
# 15183         197.658788          67.553529         105.990786
# 15184         167.796669         261.942257         294.930882
# 15185           4.266017          37.223373          16.589862
# 15186          18.486074          99.262329          42.396314
#
#                                       seq                  #Locus MIRNA  \
# 15182                CUUAAGGUAGCCAAAUGCCU
# 15183               UUUCGUGAAGGCUUCUAACUU  1B:578093667-578094261    N5
# 15184                    CGAAAGAUGGUGAACU
# 15185              UCGGUCCAUAUCCGGUGUGGGC
# 15186  UAAAUACAGGCGAGAGACCGAUAGCGAACAAGUA
#
#       DicerCall
# 15182
# 15183        21
# 15184
# 15185
# 15186

# %%
df_deg_res[df_deg_res.MIRNA == 'Y']
# Out:
#                 Gene      baseMean  log2FoldChange     lfcSE      stat  \
# 607    Cluster_33754   2990.897346       -1.092349  0.160402 -6.810064
# 3093    Cluster_9839    323.635553       -1.796546  0.330720 -5.432230
# 3760   Cluster_32170    289.998277       -1.198635  0.228737 -5.240240
# 5506   Cluster_17194    215.195641       -1.343073  0.275625 -4.872829
# 9590   Cluster_18555    867.793001       -1.400455  0.326071 -4.294941
# 10489  Cluster_35737    222.177723       -1.029754  0.250739 -4.106881
# 11310  Cluster_16054  12198.538549       -0.715709  0.182832 -3.914578
# 12061   Cluster_6291    311.504475       -1.578261  0.421775 -3.741952
# 12236  Cluster_28963    839.633466       -0.659671  0.178066 -3.704650
# 12967  Cluster_16796   3455.085821       -0.942752  0.263969 -3.571450
# 14629  Cluster_27225    227.433507       -1.047406  0.317616 -3.297716
#
#              pvalue          padj  X21dpiR1C.trimmed  X21dpiR3C.trimmed  \
# 607    9.755511e-12  1.940512e-09        4201.942964        3943.221716
# 3093   5.565415e-08  2.175441e-06         444.019746         561.692239
# 3760   1.603676e-07  5.156837e-06         429.941071         378.253508
# 5506   1.100114e-06  2.415538e-05         309.730847         308.575230
# 9590   1.747400e-05  2.203426e-04        1188.023565        1330.997305
# 10489  4.010378e-05  4.623595e-04         324.892497         271.603082
# 11310  9.056256e-05  9.683117e-04       15209.300769       15123.030274
# 12061  1.825961e-04  1.830805e-03         598.885170         335.593338
# 12236  2.116828e-04  2.092091e-03        1013.664591        1043.752160
# 12967  3.550097e-04  3.310833e-03        5185.284255        3909.093580
# 14629  9.747453e-04  8.057805e-03         349.800922         263.071048
#
#        X21dpiR1T.trimmed  X21dpiR3T.trimmed                     seq  \
# 607          1903.217292        1915.207413   UGUAGAUACUCCCUAAGGCUU
# 3093          122.009946         166.820280    AGGCGGUUACCUUGGCUAGC
# 3760          181.291615         170.506916   UGUAGAUACUCCCUAAGGCUU
# 5506          136.485702         105.990786    UAGCCAAGAAUGACUUGCCU
# 9590          385.330846         566.820288    GGUGGGUCUUCUUGGCUAGC
# 10489         147.514850         144.700464   UGUAGAUACUCCCUAAGGCUU
# 11310        8648.919726        9812.903429  UACUGUGGGCACUUAUUUGACA
# 12061         158.543998         152.995395   UGCCAAAGGAGAGUUGCCCUG
# 12236         673.467329         627.649783   UCGCUUGGUGCAGAUCGGGAC
# 12967        2338.868624        2387.096824  AUGCCGUGUUGUUCUGAAAGAA
# 14629         133.728415         163.133644  UGGGCAAGUCAUCCUGGCUACC
#
#                        #Locus MIRNA DicerCall
# 607        7B:9130339-9130430     Y        21
# 3093   2D:360310978-360311149     Y        20
# 3760     7A:72699174-72699257     Y        21
# 5506   4A:494638245-494638452     Y        21
# 9590   4B:117381111-117381289     Y        20
# 10489    7D:68403780-68403911     Y        21
# 11310  3D:544447377-544447613     Y        22
# 12061  2A:652328872-652329011     Y        21
# 12236  6B:103294141-103294344     Y        21
# 12967  4A:154525375-154525580     Y        22
# 14629  5D:549199161-549199281     Y        22

# %%
len(df_deg_res[df_deg_res.MIRNA == 'Y'].index)
# Out:
# 11

# %%
df_deg_res.to_csv(data_dir + '/res/' + lb + '/deg_data.csv', sep='\t', index=None)

# %%
len(df_deg_res.index)
# Out:
# 15187

# %%
#save fasta
buffer_seqs = []
for k,v in df_deg_res.iterrows():
    new_id = v.Gene
    new_desc = 'chr:%s log2fc:%f size:%i dicercall:%s miRNA:%s' % (v['#Locus'],  v.log2FoldChange, len(v.seq), v.DicerCall, v.MIRNA)
    seq = v.seq
    record = SeqRecord(Seq(seq), id=new_id, description=new_desc)
    buffer_seqs.append(record)
SeqIO.write(buffer_seqs, output_fasta, "fasta")
# Out:
# 15187

# %%
output_fasta
# Out:
# 'data/res/iwgsc_4_2_19//sRNA_DEG.fasta'

# %%
df_res = pd.merge(df_deg, df_blast[['qseqid','sseqid']], left_on='Gene', right_on='qseqid', how='left')
df_res = df_res.drop(['qseqid'], axis=1)
df_res.rename(columns={'sseqid': 'miRBASE'}, inplace=True)
df_res = df_res.replace(np.nan, '', regex=True)
print(len(df_res.index))
df_res.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-3196aa4fa44f> in <module>()
# ----> 1 df_res = pd.merge(df_deg, df_blast[['qseqid','sseqid']], left_on='Gene', right_on='qseqid', how='left')
#       2 df_res = df_res.drop(['qseqid'], axis=1)
#       3 df_res.rename(columns={'sseqid': 'miRBASE'}, inplace=True)
#       4 df_res = df_res.replace(np.nan, '', regex=True)
#       5 print(len(df_res.index))
#
# NameError: name 'df_blast' is not defined

# %%
#count DEG len for downregulated
df_down = df_deg[df_deg.log2FoldChange < 0]
y21 = len(df_down[df_down.Gene.isin(df_res[df_res.DicerCall.isin(['21'])].Name)].index)
y22 = len(df_down[df_down.Gene.isin(df_res[df_res.DicerCall.isin(['22'])].Name)].index)
y23 = len(df_down[df_down.Gene.isin(df_res[df_res.DicerCall.isin(['23'])].Name)].index)
y24 = len(df_down[df_down.Gene.isin(df_res[df_res.DicerCall.isin(['24'])].Name)].index)
(y21, y22, y23, y24)
# Out:
# (159, 37, 5, 1974)

# %%
#count DEG len for upregulated
df_up = df_deg[df_deg.log2FoldChange > 0]
y21 = len(df_up[df_up.Gene.isin(df_res[df_res.DicerCall.isin(['21'])].Name)].index)
y22 = len(df_up[df_up.Gene.isin(df_res[df_res.DicerCall.isin(['22'])].Name)].index)
y23 = len(df_up[df_up.Gene.isin(df_res[df_res.DicerCall.isin(['23'])].Name)].index)
y24 = len(df_up[df_up.Gene.isin(df_res[df_res.DicerCall.isin(['24'])].Name)].index)
(y21, y22, y23, y24)
# Out:
# (39, 4, 1, 13)

# %%
#count DEG len
y21 = len(df_deg[df_deg.Gene.isin(df_res[df_res.DicerCall.isin(['21'])].Name)].index)
y22 = len(df_deg[df_deg.Gene.isin(df_res[df_res.DicerCall.isin(['22'])].Name)].index)
y23 = len(df_deg[df_deg.Gene.isin(df_res[df_res.DicerCall.isin(['23'])].Name)].index)
y24 = len(df_deg[df_deg.Gene.isin(df_res[df_res.DicerCall.isin(['24'])].Name)].index)
(y21, y22, y23, y24)
# Out:
# (263, 45, 9, 2320)
